# %% [markdown]
# ## Predict Product Prices
#
# Selecting our model and evaluating the base model against the task.
#
# Keep in mind: our base model has 3 billion params, quantized down to 4 bits
# Compared with GPT-4o at TRILLIONS of params!

# %%
# pip installs - ignore the error message!

# !pip install -q datasets requests torch peft bitsandbytes transformers trl accelerate sentencepiece tiktoken matplotlib

# %%
# imports

import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments, set_seed
from peft import LoraConfig, PeftModel
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
import matplotlib.pyplot as plt

# %%
# Tokenizers

LLAMA_3_1 = "meta-llama/Llama-3.2-1B"
QWEN_2_5 = "Qwen/Qwen2.5-7B"
GEMMA_2 = "google/gemma-2-9b"
PHI_3 = "microsoft/Phi-3-medium-4k-instruct"

# Constants

BASE_MODEL = LLAMA_3_1
HF_USER = "ed-donner"
DATASET_NAME = f"{HF_USER}/pricer-data"
MAX_SEQUENCE_LENGTH = 182
QUANT_4_BIT = True

# Used for writing to output in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %matplotlib inline

# %% [markdown]
# ### Log in to HuggingFace

# %%
# Log in to HuggingFace

hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
def investigate_tokenizer(model_name):
  print("Investigating tokenizer for", model_name)
  tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
  for number in [0, 1, 10, 100, 999, 1000]:
    tokens = tokenizer.encode(str(number), add_special_tokens=False)
    print(f"The tokens for {number}: {tokens}")

# %%
# Now we will try this with each model: LLAMA_3_1, QWEN_2_5, GEMMA_2, PHI_3

investigate_tokenizer(PHI_3)
# Out:
# Investigating tokenizer for microsoft/Phi-3-medium-4k-instruct
# The tokens for 0: [29871, 29900]
# The tokens for 1: [29871, 29896]
# The tokens for 10: [29871, 29896, 29900]
# The tokens for 100: [29871, 29896, 29900, 29900]
# The tokens for 999: [29871, 29929, 29929, 29929]
# The tokens for 1000: [29871, 29896, 29900, 29900, 29900]

# %% [markdown]
# # Load our data
#
# We uploaded it to Hugging Face, so it's easy to retrieve it now

# %%
dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']
# Out:
# README.md:   0%|          | 0.00/416 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/185M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/914k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/400000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
test[0]
# Out:
# {'text': "How much does this cost to the nearest dollar?\n\nOEM AC Compressor w/A/C Repair Kit For Ford F150 F-150 V8 & Lincoln Mark LT 2007 2008 - BuyAutoParts NEW\nAs one of the world's largest automotive parts suppliers, our parts are trusted every day by mechanics and vehicle owners worldwide. This A/C Compressor and Components Kit is manufactured and tested to the strictest OE standards for unparalleled performance. Built for trouble-free ownership and 100% visually inspected and quality tested, this A/C Compressor and Components Kit is backed by our 100% satisfaction guarantee. Guaranteed Exact Fit for easy installation 100% BRAND NEW, premium ISO/TS 16949 quality - tested to meet or exceed OEM specifications Engineered for superior durability, backed by industry-leading unlimited-mileage warranty Included in this K\n\nPrice is $",
#  'price': 374.41}

# %% [markdown]
# # Prepare our Base Llama Model for evaluation
#
# Load our base model with 4 bit quantization and try out 1 example

# %%
## pick the right quantization

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

print(f"Memory footprint: {base_model.get_memory_footprint() / 1e9:.1f} GB")
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# Memory footprint: 1.0 GB

# %%
def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','').replace('$','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
extract_price("Price is $999 blah blah so cheap")
# Out:
# 999.0

# %%
def model_predict(prompt):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to("cuda")
    attention_mask = torch.ones(inputs.shape, device="cuda")
    outputs = base_model.generate(inputs, max_new_tokens=4, attention_mask=attention_mask, num_return_sequences=1)
    response = tokenizer.decode(outputs[0])
    return extract_price(response)

# %%
model_predict(test[0]['text'])
# Out:
# 1999.0

# %% [markdown]
# # Evaluation!
#
# Trying out our base Llama 3.1 model against the Test dataset

# %%
class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint["text"])
        truth = datapoint["price"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
Tester.test(model_predict, test)
# Out:
# 1: Guess: $1,999.00 Truth: $374.41 Error: $1,624.59 SLE: 2.80 Item: OEM AC Compressor w/...
# 2: Guess: $7.00 Truth: $225.11 Error: $218.11 SLE: 11.17 Item: Motorcraft YB3125 Fa...
# 3: Guess: $7.99 Truth: $61.68 Error: $53.69 SLE: 3.77 Item: Dorman Front Washer ...
# 4: Guess: $299.00 Truth: $599.99 Error: $300.99 SLE: 0.48 Item: HP Premium HD Plus T...
# 5: Guess: $7.00 Truth: $16.99 Error: $9.99 SLE: 0.66 Item: Super Switch Pickup ...
# 6: Guess: $25.00 Truth: $31.99 Error: $6.99 SLE: 0.06 Item: Horror Bookmarks, Re...
# 7: Guess: $1,999.00 Truth: $101.79 Error: $1,897.21 SLE: 8.81 Item: SK6241 - Stinger 4 G...
# 8: Guess: $1,999.00 Truth: $289.00 Error: $1,710.00 SLE: 3.73 Item: Godox ML60Bi LED Lig...
# 9: Guess: $1,299.00 Truth: $635.86 Error: $663.14 SLE: 0.51 Item: Randall G3 Plus Comb...
# 10: Guess: $7.00 Truth: $65.99 Error: $58.99 SLE: 4.52 Item: HOLDWILL 6 Pack LED ...
# 11: Guess: $1,999.00 Truth: $254.21 Error: $1,744.79 SLE: 4.24 Item: Viking Horns 3 Gallo...
# 12: Guess: $7.00 Truth: $412.99 Error: $405.99 SLE: 15.57 Item: CURT 70110 Custom To...
# 13: Guess: $7.00 Truth: $205.50 Error: $198.50 SLE: 10.57 Item: Solar HAMMERED BRONZ...
# 14: Guess: $19.99 Truth: $248.23 Error: $228.24 SLE: 6.12 Item: COSTWAY Electric Tum...
# 15: Guess: $299.00 Truth: $399.00 Error: $100.00 SLE: 0.08 Item: FREE SIGNAL TV Trans...
# 16: Guess: $299.00 Truth: $373.94 Error: $74.94 SLE: 0.05 Item: Bilstein 5100 Monotu...
# 17: Guess: $19.99 Truth: $92.89 Error: $72.90 SLE: 2.24 Item: Sangean K-200 Multi-...
# 18: Guess: $19.99 Truth: $51.99 Error: $32.00 SLE: 0.86 Item: Charles Leonard Magn...
# 19: Guess: $1,999.00 Truth: $179.00 Error: $1,820.00 SLE: 5.80 Item: Gigabyte AMD Radeon ...
# 20: Guess: $6.99 Truth: $19.42 Error: $12.43 SLE: 0.88 Item: 3dRose LLC 8 x 8 x 0...
# 21: Guess: $85.00 Truth: $539.95 Error: $454.95 SLE: 3.38 Item: ROKINON 85mm F1.4 Au...
# 22: Guess: $25.00 Truth: $147.67 Error: $122.67 SLE: 3.04 Item: Headlight Assembly C...
# 23: Guess: $19.99 Truth: $24.99 Error: $5.00 SLE: 0.05 Item: ASI NAUTICAL 2.5 Inc...
# 24: Guess: $19.99 Truth: $149.00 Error: $129.01 SLE: 3.87 Item: Behringer TUBE OVERD...
# 139: Guess: $25.00 Truth: $31.49 Error: $6.49 SLE: 0.05 Item: F FIERCE CYCLE 251pc...
# 140: Guess: $7.99 Truth: $196.00 Error: $188.01 SLE: 9.53 Item: Flash Furniture 4 Pk...
# 141: Guess: $7.99 Truth: $78.40 Error: $70.41 SLE: 4.75 Item: B&M 30287 Throttle V...
# 142: Guess: $1.00 Truth: $116.25 Error: $115.25 SLE: 16.57 Item: Gates TCK226 PowerGr...
# 143: Guess: $1.00 Truth: $112.78 Error: $111.78 SLE: 16.33 Item: Monroe Shocks & Stru...
# 144: Guess: $1.00 Truth: $27.32 Error: $26.32 SLE: 7.02 Item: Feit Electric 35W EQ...
# 145: Guess: $7.00 Truth: $145.91 Error: $138.91 SLE: 8.47 Item: Yellow Jacket 2806 C...
# 146: Guess: $7.99 Truth: $171.09 Error: $163.10 SLE: 8.71 Item: Garage-Pro Tailgate ...
# 147: Guess: $7.48 Truth: $167.95 Error: $160.47 SLE: 8.95 Item: 3M Perfect It Buffin...
# 148: Guess: $19.99 Truth: $28.49 Error: $8.50 SLE: 0.12 Item: Chinese Style Dollho...
# 149: Guess: $25.00 Truth: $122.23 Error: $97.23 SLE: 2.42 Item: Generic NRG Innovati...
# 150: Guess: $19.99 Truth: $32.99 Error: $13.00 SLE: 0.23 Item: Learning Resources C...
# 151: Guess: $0.00 Truth: $71.20 Error: $71.20 SLE: 18.31 Item: Bosch Automotive 154...
# 152: Guess: $7.99 Truth: $112.75 Error: $104.76 SLE: 6.44 Item: Case of 24-2 Inch Bl...
# 153: Guess: $1.00 Truth: $142.43 Error: $141.43 SLE: 18.26 Item: MOCA Engine Water Pu...
# 154: Guess: $25.00 Truth: $398.99 Error: $373.99 SLE: 7.47 Item: SAREMAS Foot Step Ba...
# 155: Guess: $1,299.00 Truth: $449.00 Error: $850.00 SLE: 1.13 Item: Gretsch G9210 Square...
# 156: Guess: $19.99 Truth: $189.00 Error: $169.01 SLE: 4.85 Item: NikoMaku Mirror Dash...
# 157: Guess: $25.00 Truth: $120.91 Error: $95.91 SLE: 2.39 Item: Fenix HP25R v2.0 USB...
# 158: Guess: $19.99 Truth: $203.53 Error: $183.54 SLE: 5.18 Item: R&L Racing Heavy Dut...
# 159: Guess: $299.00 Truth: $349.99 Error: $50.99 SLE: 0.02 Item: Garmin GPSMAP 64sx, ...
# 160: Guess: $7.99 Truth: $34.35 Error: $26.36 SLE: 1.87 Item: Brown 5-7/8 X 8-1/2 ...
# 161: Guess: $19.99 Truth: $384.99 Error: $365.00 SLE: 8.48 Item: GAOMON PD2200 Pen Di...
# 162: Guess: $1,999.00 Truth: $211.00 Error: $1,788.00 SLE: 5.04 Item: VXMOTOR for 97-03 Fo...
# 163: Guess: $1,999.00 Truth: $129.00 Error: $1,870.00 SLE: 7.47 Item: HP EliteBook 2540p I...
# 164: Guess: $7.00 Truth: $111.45 Error: $104.45 SLE: 6.99 Item: Green EPX Mixing Noz...
# 165: Guess: $1.00 Truth: $81.12 Error: $80.12 SLE: 13.80 Item: Box Partners 6 1/4 x...
# 166: Guess: $25.00 Truth: $457.08 Error: $432.08 SLE: 8.23 Item: Vixen Air 1/2 NPT Ai...
# 167: Guess: $25.00 Truth: $49.49 Error: $24.49 SLE: 0.44 Item: Smart Floor Lamp, Mu...
# 168: Guess: $1.00 Truth: $80.56 Error: $79.56 SLE: 13.75 Item: SOZG 324mm Wheelbase...
# 169: Guess: $25.00 Truth: $278.39 Error: $253.39 SLE: 5.64 Item: Mickey Thompson ET S...
# 170: Guess: $1.00 Truth: $364.50 Error: $363.50 SLE: 27.12 Item: Pirelli 106W XL RFT ...
# 171: Guess: $1,800.00 Truth: $378.99 Error: $1,421.01 SLE: 2.42 Item: Torklift C3212 Rear ...
# 172: Guess: $1,800.00 Truth: $165.28 Error: $1,634.72 SLE: 5.68 Item: Cardone Remanufactur...
# 173: Guess: $25.00 Truth: $56.74 Error: $31.74 SLE: 0.64 Item: Kidde AccessPoint 00...
# 174: Guess: $7.00 Truth: $307.95 Error: $300.95 SLE: 13.35 Item: 3M Protecta Self Ret...
# 175: Guess: $7.00 Truth: $38.00 Error: $31.00 SLE: 2.51 Item: Plantronics Wired He...
# 176: Guess: $19.99 Truth: $53.00 Error: $33.01 SLE: 0.89 Item: Logitech K750 Wirele...
# 177: Guess: $299.00 Truth: $498.00 Error: $199.00 SLE: 0.26 Item: Olympus PEN E-PL9 Bo...
# 178: Guess: $7.99 Truth: $53.99 Error: $46.00 SLE: 3.28 Item: Beck/Arnley Hub & Be...
# 179: Guess: $25.00 Truth: $350.00 Error: $325.00 SLE: 6.77 Item: Eibach Pro-Kit Perfo...
# 180: Guess: $19.99 Truth: $299.95 Error: $279.96 SLE: 7.09 Item: LEGO DC Batman 1989 ...
# 181: Guess: $1.00 Truth: $94.93 Error: $93.93 SLE: 14.98 Item: Kingston Brass Resto...
# 182: Guess: $1,999.00 Truth: $379.00 Error: $1,620.00 SLE: 2.76 Item: Polk Vanishing Serie...
# 183: Guess: $19.99 Truth: $299.95 Error: $279.96 SLE: 7.09 Item: Spec-D Tuning LED Pr...
# 184: Guess: $19.99 Truth: $24.99 Error: $5.00 SLE: 0.05 Item: RICHMOND & FINCH Air...
# 185: Guess: $1.00 Truth: $41.04 Error: $40.04 SLE: 9.27 Item: LFA Industries - mm ...
# 186: Guess: $25.00 Truth: $327.90 Error: $302.90 SLE: 6.44 Item: SAUTVS LED Headlight...
# 187: Guess: $19.99 Truth: $10.99 Error: $9.00 SLE: 0.31 Item: 2 Pack Combo Womens ...
# 188: Guess: $19.99 Truth: $14.99 Error: $5.00 SLE: 0.07 Item: Arepa - Venezuelan c...
# 189: Guess: $1.00 Truth: $84.95 Error: $83.95 SLE: 14.14 Item: Schlage Lock Company...
# 190: Guess: $25.00 Truth: $111.00 Error: $86.00 SLE: 2.13 Item: Techni Mobili White ...
# 191: Guess: $7.00 Truth: $123.73 Error: $116.73 SLE: 7.54 Item: Special Lite Product...
# 192: Guess: $25.00 Truth: $557.38 Error: $532.38 SLE: 9.41 Item: Tascam Digital Porta...
# 193: Guess: $7.99 Truth: $95.55 Error: $87.56 SLE: 5.64 Item: Glow Lighting Vista ...
# 194: Guess: $19.99 Truth: $154.00 Error: $134.01 SLE: 4.00 Item: Z3 Wind Deflector, S...
# 195: Guess: $299.00 Truth: $198.99 Error: $100.01 SLE: 0.16 Item: Olympus E-20 5MP Dig...
# 196: Guess: $1,800.00 Truth: $430.44 Error: $1,369.56 SLE: 2.04 Item: PHYNEDI 1 1000 World...
# 197: Guess: $19.99 Truth: $45.67 Error: $25.68 SLE: 0.64 Item: YANGHUAN Unstable Un...
# 198: Guess: $25.00 Truth: $249.00 Error: $224.00 SLE: 5.12 Item: Interlogix NetworX T...
# 199: Guess: $25.00 Truth: $42.99 Error: $17.99 SLE: 0.28 Item: Steering Damper,Univ...
# 200: Guess: $1.00 Truth: $181.33 Error: $180.33 SLE: 20.36 Item: Amprobe TIC 410A Hot...
# 201: Guess: $1.00 Truth: $6.03 Error: $5.03 SLE: 1.58 Item: MyCableMart 3.5mm Pl...
# 202: Guess: $19.99 Truth: $29.99 Error: $10.00 SLE: 0.15 Item: OtterBox + Pop Symme...
# 203: Guess: $1,999.00 Truth: $899.00 Error: $1,100.00 SLE: 0.64 Item: Dell XPS Desktop ( I...
# 204: Guess: $19.58 Truth: $399.99 Error: $380.41 SLE: 8.82 Item: Franklin Iron Works ...
# 205: Guess: $1.00 Truth: $4.66 Error: $3.66 SLE: 1.08 Item: Avery Legal Dividers...
# 206: Guess: $7.99 Truth: $261.41 Error: $253.42 SLE: 11.38 Item: Moen 8346 Commercial...
# 207: Guess: $25.00 Truth: $136.97 Error: $111.97 SLE: 2.79 Item: Carlisle Versa Trail...
# 208: Guess: $44.00 Truth: $79.00 Error: $35.00 SLE: 0.33 Item: SUNWAYFOTO 44mm Trip...
# 209: Guess: $1,999.00 Truth: $444.99 Error: $1,554.01 SLE: 2.25 Item: NanoBeam AC 4 Units ...
# 210: Guess: $1,999.00 Truth: $411.94 Error: $1,587.06 SLE: 2.49 Item: WULF 4 Front 2 Rear ...
# 211: Guess: $25.00 Truth: $148.40 Error: $123.40 SLE: 3.06 Item: Alera ALEVABFMC Vale...
# 212: Guess: $19.99 Truth: $244.99 Error: $225.00 SLE: 6.06 Item: YU-GI-OH! Ignition A...
# 213: Guess: $48.00 Truth: $86.50 Error: $38.50 SLE: 0.34 Item: 48 x 36 Extra-Large ...
# 214: Guess: $1,999.00 Truth: $297.95 Error: $1,701.05 SLE: 3.61 Item: Dell Latitude D620 R...
# 215: Guess: $1,999.00 Truth: $399.99 Error: $1,599.01 SLE: 2.58 Item: acer Aspire 5 Laptop...
# 216: Guess: $25.00 Truth: $599.00 Error: $574.00 SLE: 9.85 Item: Elk 30 by 6-Inch Viv...
# 217: Guess: $19.99 Truth: $105.99 Error: $86.00 SLE: 2.65 Item: Barbie Top Model Dol...
# 218: Guess: $299.00 Truth: $689.00 Error: $390.00 SLE: 0.69 Item: Danby Designer 20-In...
# 219: Guess: $1.00 Truth: $404.99 Error: $403.99 SLE: 28.23 Item: FixtureDisplays® Met...
# 220: Guess: $1.00 Truth: $207.76 Error: $206.76 SLE: 21.60 Item: ACDelco GM Original ...
# 221: Guess: $40.00 Truth: $171.82 Error: $131.82 SLE: 2.07 Item: EBC Premium Street B...
# 222: Guess: $299.00 Truth: $293.24 Error: $5.76 SLE: 0.00 Item: FXR Men's Boost FX J...
# 223: Guess: $25.00 Truth: $374.95 Error: $349.95 SLE: 7.14 Item: SuperATV Scratch Res...
# 224: Guess: $19.99 Truth: $111.99 Error: $92.00 SLE: 2.83 Item: SBU 3 Layer All Weat...
# 225: Guess: $7.00 Truth: $42.99 Error: $35.99 SLE: 2.91 Item: 2 Pack Outdoor Broch...
# 226: Guess: $1.00 Truth: $116.71 Error: $115.71 SLE: 16.61 Item: Monroe Shocks & Stru...
# 227: Guess: $1.00 Truth: $118.61 Error: $117.61 SLE: 16.74 Item: Elements of Design M...
# 228: Guess: $7.48 Truth: $147.12 Error: $139.64 SLE: 8.18 Item: GM Genuine Parts Air...
# 229: Guess: $19.99 Truth: $119.99 Error: $100.00 SLE: 3.07 Item: Baseus USB C Docking...
# 230: Guess: $25.00 Truth: $369.98 Error: $344.98 SLE: 7.07 Item: Whitehall™ Personali...
# 231: Guess: $19.99 Truth: $315.55 Error: $295.56 SLE: 7.36 Item: Pro Circuit Works Pi...
# 232: Guess: $1,800.00 Truth: $190.99 Error: $1,609.01 SLE: 5.01 Item: HYANKA 15 1200W Prof...
# 233: Guess: $25.00 Truth: $155.00 Error: $130.00 SLE: 3.21 Item: Bluetooth X6BT Card ...
# 234: Guess: $25.00 Truth: $349.99 Error: $324.99 SLE: 6.77 Item: AIRAID Cold Air Inta...
# 235: Guess: $1,999.00 Truth: $249.99 Error: $1,749.01 SLE: 4.31 Item: Bostingner Shower Fa...
# 236: Guess: $19.99 Truth: $42.99 Error: $23.00 SLE: 0.55 Item: PIT66 Front Bumper T...
# 237: Guess: $19.99 Truth: $17.99 Error: $2.00 SLE: 0.01 Item: Caseology Bumpy Comp...
# 238: Guess: $7.50 Truth: $425.00 Error: $417.50 SLE: 15.32 Item: Fleck 2510 Timer Mec...
# 239: Guess: $1,999.00 Truth: $249.99 Error: $1,749.01 SLE: 4.31 Item: Haloview MC7108 Wire...
# 240: Guess: $7.00 Truth: $138.23 Error: $131.23 SLE: 8.16 Item: Schmidt Spiele - Man...
# 241: Guess: $7.00 Truth: $414.99 Error: $407.99 SLE: 15.61 Item: Corsa 14333 Tip Kit ...
# 242: Guess: $1.00 Truth: $168.28 Error: $167.28 SLE: 19.70 Item: Hoshizaki FM116A Fan...
# 243: Guess: $25.00 Truth: $199.99 Error: $174.99 SLE: 4.18 Item: BAINUO Antler Chande...
# 244: Guess: $19.99 Truth: $126.70 Error: $106.71 SLE: 3.26 Item: DNA MOTORING Smoke L...
# 245: Guess: $1.00 Truth: $5.91 Error: $4.91 SLE: 1.54 Item: Wera Stainless 3840/...
# 246: Guess: $19.99 Truth: $193.06 Error: $173.07 SLE: 4.95 Item: Celestron - PowerSee...
# 247: Guess: $299.00 Truth: $249.99 Error: $49.01 SLE: 0.03 Item: NHOPEEW Android Car ...
# 248: Guess: $7.00 Truth: $64.12 Error: $57.12 SLE: 4.40 Item: Other Harmonica A)
# F...
# 249: Guess: $25.00 Truth: $114.99 Error: $89.99 SLE: 2.24 Item: Harley Air Filter Ve...
# 250: Guess: $1,999.00 Truth: $926.00 Error: $1,073.00 SLE: 0.59 Item: Elite Screens Edge F...
